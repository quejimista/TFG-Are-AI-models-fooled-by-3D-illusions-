# %% [markdown]
# # MiDaS CNN Pipeline
# **Ivan Martín Campoy | UAB, 2025/26**
#
# This notebook runs the MiDaS CNN-based depth estimation model across all experimental
# datasets, serving as a cross-architecture comparison against the ViT-based Depth Anything
# models in `tfg_pipeline.ipynb`.
#
# MiDaS (`Intel/dpt-hybrid-midas`) uses a DPT (Dense Prediction Transformer) head on top
# of a hybrid CNN-ViT backbone trained on multiple datasets simultaneously. Unlike the
# Depth Anything family, it does not use semi-supervised training on unlabelled data.
#
# All paths are relative to the `notebooks/` folder.
# Results are written to `../results/depth_map_comparisons/midas/`,
# `../results/roi_analysis/midas/`, and `../results/psychophysics/midas/`.
#
# Sections:
# 1. Imports and Environment Setup
# 2. Model Loading
# 3. Inference and Depth Map Generation
# 4. ROI Analysis (Depth Gap Measurement)
# 5. PSE and JND Analysis
# 6. Video Export

# %% [markdown]
# ## 1. Imports and Environment Setup

# %%
#Libraries

from PIL import Image 
import matplotlib.pyplot as plt 
import os 
import re #regular expressions
import torch
import numpy as np
from PIL import ImageFilter
from transformers import pipeline
import pandas as pd

# %% [markdown]
# ## 2. Model Loading
#
# MiDaS is loaded through the HuggingFace `transformers` pipeline using the
# `depth-estimation` task. The `dpt-hybrid-midas` checkpoint uses a ViT-Hybrid backbone
# (ResNet-50 + ViT) with a DPT head, trained on a mix of ReDWeb, DIML, MegaDepth,
# WSVD, TartanAir and other datasets.
#
# The `size` parameter is left at the default 384px to match the resolution used
# in the Depth Anything runs and keep comparisons consistent.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu" #set device as GPU if available
print(f"Using Device: {device}")
# Out:
# Using Device: cuda

# %%
#loading model/s
models = {
    "MiDaS": "Intel/dpt-hybrid-midas" #load midas cnn baseline from hugging face hub
}

pipelines = {}
print("\nLoading CNN models")
for version, repo in models.items():
    try:
        #initialize the depth estimation pipeline for the cnn architecture
        pipelines[version] = pipeline(task="depth-estimation", model=repo, device=device, torch_dtype=torch.float32)
        print(f" {version} loaded successfully.")
    except Exception as e:
        print(f" Couldn't Load {version}. Error: {e}")
# Out:
# Loading CNN models
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/414 [00:00<?, ?it/s]
# The image processor of type `DPTImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
#  MiDaS loaded successfully.

# %% [markdown]
# ## 3. Inference and Depth Map Generation
#
# ### 3.1 Core functions: `compare_single_image` and `process_dataset`
#
# These functions mirror the design of the main pipeline. `compare_single_image` produces
# a two-panel output (original + MiDaS depth map) instead of four panels, since only one
# model is evaluated here.
#
# One difference from the Depth Anything pipeline: MiDaS consistently outputs higher
# values for closer objects (same convention as V1 and V2), so no depth map inversion
# is needed.

# %%
def compare_single_image(image_path, save_path=None):
    """
    runs the available cnn model (midas) and plots it alongside the original image
    """
    try:
        available_models = sorted(pipelines.keys())
        if not available_models: return

        #setup naming
        base_name = os.path.splitext(os.path.basename(image_path))[0]
        clean_name = re.sub(r'\d+', '', base_name).replace('_', ' ').strip().title()

        img_pil = Image.open(image_path).convert("RGB")
        
        results = {}
        for version in available_models:
            model = pipelines[version]
            #midas pipeline returns the standard dictionary structure like depth anything v1/v2
            res = model(img_pil, timeout=None)
            results[version] = res["predicted_depth"].squeeze().cpu().numpy()

        num_plots = len(results) + 1
        fig, axes = plt.subplots(1, num_plots, figsize=(5 * num_plots, 5))
        if num_plots == 1: axes = [axes]
        fig.suptitle(clean_name, fontsize=14, fontweight='bold', y=0.98)

        #0. original image
        axes[0].imshow(img_pil)
        axes[0].set_title("Original Image", fontsize=10, fontweight='bold')
        axes[0].axis('off')

        #1-n. depth maps
        for i, version in enumerate(available_models):
            depth_map_ptr = np.array(results[version])
            
            #basic normalization: 0 to 1
            d_min, d_max = depth_map_ptr.min(), depth_map_ptr.max()
            depth_norm = (depth_map_ptr - d_min) / (d_max - d_min + 1e-8)

            #midas output usually represents closer objects with higher values (matches v1/v2)
            axes[i+1].imshow(depth_norm, cmap='inferno', interpolation="bilinear")
            axes[i+1].set_title(f"{version} CNN", fontsize=10, fontweight='bold')
            axes[i+1].axis('off')

        plt.tight_layout(rect=[0, 0, 1, 0.92])

        if save_path:
            plt.savefig(save_path, dpi=200, bbox_inches='tight')
            plt.close(fig)
        else:
            plt.show()

    except Exception as e:
        print(f" error in compare_single_image: {e}")

def process_dataset(input_folder="3D_illusions", output_folder="results_cnn"):
    """
    automates processing for the entire directory structure targeting the cnn pipeline
    """
    #final check before starting
    print(f"models currently loaded: {list(pipelines.keys())}")
    
    total = 0
    if not os.path.exists(input_folder):
        print(f" error: input folder '{input_folder}' not found.")
        return

    for root, dirs, files in os.walk(input_folder):
        for filename in files:
            if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                img_path = os.path.join(root, filename)
                
                #maintain subdirectory structure
                rel_path = os.path.relpath(root, input_folder)
                target_dir = os.path.join(output_folder, rel_path)
                os.makedirs(target_dir, exist_ok=True)
                
                save_path = os.path.join(target_dir, f"cmp_{filename}")
                
                print(f" processing -> {filename}")
                compare_single_image(img_path, save_path=save_path)
                total += 1

    print(f"dataset processing complete. total images: {total}")

# %% [markdown]
# ### 3.2 Batch processing over all datasets
#
# Each `process_dataset` call walks the input folder recursively and saves a `cmp_*.png`
# comparison for every image found, preserving the subfolder structure in the output.
#
# The four datasets covered are:
# - **Baseline dataset** — the curated 3D illusion collection
# - **Synthetic** — the fifteen Corridor Illusion ablation variants
# - **Minecraft** — the voxel laboratory experiments
# - **Psychophysics** — the 30-frame stimulus sequences (all 15 experiments)

# %%
#Experiments:

process_dataset(input_folder="../data/dataset", output_folder="../results/depth_map_comparisons/midas/baseline_dataset") #for the original 3D illusions dataset
process_dataset(input_folder="../data/synthetic/corridor_illusion", output_folder="../results/depth_map_comparisons/midas/synthetic") #for the original 3D illusions dataset
process_dataset(input_folder="../data/minecraft", output_folder="../results/depth_map_comparisons/midas/minecraft") #Minecraft Experiments
process_dataset(input_folder="../data/psychophysics", output_folder="../results/depth_map_comparisons/midas/psychophysics") #Psychophysics Experiments
# Out:
# models currently loaded: ['MiDaS']
#  processing -> contrast_000.png
#  processing -> contrast_008.png
#  processing -> contrast_016.png
#  processing -> contrast_024.png
#  processing -> contrast_033.png
#  processing -> contrast_041.png
#  processing -> contrast_049.png
#  processing -> contrast_057.png
#  processing -> contrast_066.png
#  processing -> contrast_074.png
#  processing -> contrast_082.png
#  processing -> contrast_091.png
#  processing -> contrast_099.png
#  processing -> contrast_107.png
#  processing -> contrast_115.png
#  processing -> contrast_124.png
#  processing -> contrast_132.png
#  processing -> contrast_140.png
#  processing -> contrast_148.png
#  processing -> contrast_157.png
#  processing -> contrast_165.png
#  processing -> contrast_173.png
#  processing -> contrast_182.png
#  processing -> contrast_190.png
#  processing -> contrast_198.png
#  processing -> contrast_206.png
#  processing -> contrast_215.png
#  processing -> contrast_223.png
#  processing -> contrast_231.png
#  processing -> contrast_240.png
#  processing -> blur_bias_000.png
#  processing -> blur_bias_001.png
#  processing -> blur_bias_002.png
#  processing -> blur_bias_003.png
#  processing -> blur_bias_004.png
#  processing -> blur_bias_005.png
#  processing -> blur_bias_006.png
#  processing -> blur_bias_007.png
#  processing -> blur_bias_008.png
#  processing -> blur_bias_009.png
#  processing -> blur_bias_010.png
#  processing -> blur_bias_011.png
#  processing -> blur_bias_012.png
#  processing -> blur_bias_013.png
#  processing -> blur_bias_014.png
#  processing -> blur_bias_015.png
#  processing -> blur_bias_016.png
#  processing -> blur_bias_017.png
#  processing -> blur_bias_018.png
#  processing -> blur_bias_019.png
#  processing -> blur_bias_020.png
#  processing -> blur_bias_021.png
#  processing -> blur_bias_022.png
#  processing -> blur_bias_023.png
#  processing -> blur_bias_024.png
#  processing -> blur_bias_025.png
#  processing -> blur_bias_026.png
#  processing -> blur_bias_027.png
#  processing -> blur_bias_028.png
#  processing -> blur_bias_029.png
#  processing -> ebbinghaus_000.png
#  processing -> ebbinghaus_001.png
#  processing -> ebbinghaus_002.png
#  processing -> ebbinghaus_003.png
#  processing -> ebbinghaus_004.png
#  processing -> ebbinghaus_005.png
#  processing -> ebbinghaus_006.png
#  processing -> ebbinghaus_007.png
#  processing -> ebbinghaus_008.png
#  processing -> ebbinghaus_009.png
#  processing -> ebbinghaus_010.png
#  processing -> ebbinghaus_011.png
#  processing -> ebbinghaus_012.png
#  processing -> ebbinghaus_013.png
#  processing -> ebbinghaus_014.png
#  processing -> ebbinghaus_015.png
#  processing -> ebbinghaus_016.png
#  processing -> ebbinghaus_017.png
#  processing -> ebbinghaus_018.png
#  processing -> ebbinghaus_019.png
#  processing -> ebbinghaus_020.png
#  processing -> ebbinghaus_021.png
#  processing -> ebbinghaus_022.png
#  processing -> ebbinghaus_023.png
#  processing -> ebbinghaus_024.png
#  processing -> ebbinghaus_025.png
#  processing -> ebbinghaus_026.png
#  processing -> ebbinghaus_027.png
#  processing -> ebbinghaus_028.png
#  processing -> ebbinghaus_029.png
#  processing -> figure_ground_000.png
#  processing -> figure_ground_001.png
#  processing -> figure_ground_002.png
#  processing -> figure_ground_003.png
#  processing -> figure_ground_004.png
#  processing -> figure_ground_005.png
#  processing -> figure_ground_006.png
#  processing -> figure_ground_007.png
#  processing -> figure_ground_008.png
#  processing -> figure_ground_009.png
#  processing -> figure_ground_010.png
#  processing -> figure_ground_011.png
#  processing -> figure_ground_012.png
#  processing -> figure_ground_013.png
#  processing -> figure_ground_014.png
#  processing -> figure_ground_015.png
#  processing -> figure_ground_016.png
#  processing -> figure_ground_017.png
#  processing -> figure_ground_018.png
#  processing -> figure_ground_019.png
#  processing -> figure_ground_020.png
#  processing -> figure_ground_021.png
#  processing -> figure_ground_022.png
#  processing -> figure_ground_023.png
#  processing -> figure_ground_024.png
#  processing -> figure_ground_025.png
#  processing -> figure_ground_026.png
#  processing -> figure_ground_027.png
#  processing -> figure_ground_028.png
#  processing -> figure_ground_029.png
#  processing -> ypos_050.png
#  processing -> ypos_063.png
#  processing -> ypos_077.png
#  processing -> ypos_091.png
#  processing -> ypos_105.png
#  processing -> ypos_118.png
#  processing -> ypos_132.png
#  processing -> ypos_146.png
#  processing -> ypos_160.png
#  processing -> ypos_174.png
#  processing -> ypos_187.png
#  processing -> ypos_201.png
#  processing -> ypos_215.png
#  processing -> ypos_229.png
#  processing -> ypos_243.png
#  processing -> ypos_256.png
#  processing -> ypos_270.png
#  processing -> ypos_284.png
#  processing -> ypos_298.png
#  processing -> ypos_312.png
#  processing -> ypos_325.png
#  processing -> ypos_339.png
#  processing -> ypos_353.png
#  processing -> ypos_367.png
#  processing -> ypos_381.png
#  processing -> ypos_394.png
#  processing -> ypos_408.png
#  processing -> ypos_422.png
#  processing -> ypos_436.png
#  processing -> ypos_450.png
#  processing -> face_shading_000.png
#  processing -> face_shading_001.png
#  processing -> face_shading_002.png
#  processing -> face_shading_003.png
#  processing -> face_shading_004.png
#  processing -> face_shading_005.png
#  processing -> face_shading_006.png
#  processing -> face_shading_007.png
#  processing -> face_shading_008.png
#  processing -> face_shading_009.png
#  processing -> face_shading_010.png
#  processing -> face_shading_011.png
#  processing -> face_shading_012.png
#  processing -> face_shading_013.png
#  processing -> face_shading_014.png
#  processing -> face_shading_015.png
#  processing -> face_shading_016.png
#  processing -> face_shading_017.png
#  processing -> face_shading_018.png
#  processing -> face_shading_019.png
#  processing -> face_shading_020.png
#  processing -> face_shading_021.png
#  processing -> face_shading_022.png
#  processing -> face_shading_023.png
#  processing -> face_shading_024.png
#  processing -> face_shading_025.png
#  processing -> face_shading_026.png
#  processing -> face_shading_027.png
#  processing -> face_shading_028.png
#  processing -> face_shading_029.png
#  processing -> horizon_000.png
#  processing -> horizon_001.png
#  processing -> horizon_002.png
#  processing -> horizon_003.png
#  processing -> horizon_004.png
#  processing -> horizon_005.png
#  processing -> horizon_006.png
#  processing -> horizon_007.png
#  processing -> horizon_008.png
#  processing -> horizon_009.png
#  processing -> horizon_010.png
#  processing -> horizon_011.png
#  processing -> horizon_012.png
#  processing -> horizon_013.png
#  processing -> horizon_014.png
#  processing -> horizon_015.png
#  processing -> horizon_016.png
#  processing -> horizon_017.png
#  processing -> horizon_018.png
#  processing -> horizon_019.png
#  processing -> horizon_020.png
#  processing -> horizon_021.png
#  processing -> horizon_022.png
#  processing -> horizon_023.png
#  processing -> horizon_024.png
#  processing -> horizon_025.png
#  processing -> horizon_026.png
#  processing -> horizon_027.png
#  processing -> horizon_028.png
#  processing -> horizon_029.png
#  processing -> kanizsa_000.png
#  processing -> kanizsa_001.png
#  processing -> kanizsa_002.png
#  processing -> kanizsa_003.png
#  processing -> kanizsa_004.png
#  processing -> kanizsa_005.png
#  processing -> kanizsa_006.png
#  processing -> kanizsa_007.png
#  processing -> kanizsa_008.png
#  processing -> kanizsa_009.png
#  processing -> kanizsa_010.png
#  processing -> kanizsa_011.png
#  processing -> kanizsa_012.png
#  processing -> kanizsa_013.png
#  processing -> kanizsa_014.png
#  processing -> kanizsa_015.png
#  processing -> kanizsa_016.png
#  processing -> kanizsa_017.png
#  processing -> kanizsa_018.png
#  processing -> kanizsa_019.png
#  processing -> kanizsa_020.png
#  processing -> kanizsa_021.png
#  processing -> kanizsa_022.png
#  processing -> kanizsa_023.png
#  processing -> kanizsa_024.png
#  processing -> kanizsa_025.png
#  processing -> kanizsa_026.png
#  processing -> kanizsa_027.png
#  processing -> kanizsa_028.png
#  processing -> kanizsa_029.png
#  processing -> occlusion_000.png
#  processing -> occlusion_001.png
#  processing -> occlusion_002.png
#  processing -> occlusion_003.png
#  processing -> occlusion_004.png
#  processing -> occlusion_005.png
#  processing -> occlusion_006.png
#  processing -> occlusion_007.png
#  processing -> occlusion_008.png
#  processing -> occlusion_009.png
#  processing -> occlusion_010.png
#  processing -> occlusion_011.png
#  processing -> occlusion_012.png
#  processing -> occlusion_013.png
#  processing -> occlusion_014.png
#  processing -> occlusion_015.png
#  processing -> occlusion_016.png
#  processing -> occlusion_017.png
#  processing -> occlusion_018.png
#  processing -> occlusion_019.png
#  processing -> occlusion_020.png
#  processing -> occlusion_021.png
#  processing -> occlusion_022.png
#  processing -> occlusion_023.png
#  processing -> occlusion_024.png
#  processing -> occlusion_025.png
#  processing -> occlusion_026.png
#  processing -> occlusion_027.png
#  processing -> occlusion_028.png
#  processing -> occlusion_029.png
#  processing -> ponzo_000.png
#  processing -> ponzo_001.png
#  processing -> ponzo_002.png
#  processing -> ponzo_003.png
#  processing -> ponzo_004.png
#  processing -> ponzo_005.png
#  processing -> ponzo_006.png
#  processing -> ponzo_007.png
#  processing -> ponzo_008.png
#  processing -> ponzo_009.png
#  processing -> ponzo_010.png
#  processing -> ponzo_011.png
#  processing -> ponzo_012.png
#  processing -> ponzo_013.png
#  processing -> ponzo_014.png
#  processing -> ponzo_015.png
#  processing -> ponzo_016.png
#  processing -> ponzo_017.png
#  processing -> ponzo_018.png
#  processing -> ponzo_019.png
#  processing -> ponzo_020.png
#  processing -> ponzo_021.png
#  processing -> ponzo_022.png
#  processing -> ponzo_023.png
#  processing -> ponzo_024.png
#  processing -> ponzo_025.png
#  processing -> ponzo_026.png
#  processing -> ponzo_027.png
#  processing -> ponzo_028.png
#  processing -> ponzo_029.png
#  processing -> step_00.png
#  processing -> step_01.png
#  processing -> step_02.png
#  processing -> step_03.png
#  processing -> step_04.png
#  processing -> step_05.png
#  processing -> step_06.png
#  processing -> step_07.png
#  processing -> step_08.png
#  processing -> step_09.png
#  processing -> step_10.png
#  processing -> step_11.png
#  processing -> step_12.png
#  processing -> step_13.png
#  processing -> step_14.png
#  processing -> step_15.png
#  processing -> step_16.png
#  processing -> step_17.png
#  processing -> step_18.png
#  processing -> step_19.png
#  processing -> step_20.png
#  processing -> step_21.png
#  processing -> step_22.png
#  processing -> step_23.png
#  processing -> step_24.png
#  processing -> step_25.png
#  processing -> step_26.png
#  processing -> step_27.png
#  processing -> step_28.png
#  processing -> step_29.png
#  processing -> size_010.png
#  processing -> size_012.png
#  processing -> size_014.png
#  processing -> size_017.png
#  processing -> size_019.png
#  processing -> size_022.png
#  processing -> size_024.png
#  processing -> size_026.png
#  processing -> size_029.png
#  processing -> size_031.png
#  processing -> size_034.png
#  processing -> size_036.png
#  processing -> size_038.png
#  processing -> size_041.png
#  processing -> size_043.png
#  processing -> size_046.png
#  processing -> size_048.png
#  processing -> size_051.png
#  processing -> size_053.png
#  processing -> size_055.png
#  processing -> size_058.png
#  processing -> size_060.png
#  processing -> size_063.png
#  processing -> size_065.png
#  processing -> size_067.png
#  processing -> size_070.png
#  processing -> size_072.png
#  processing -> size_075.png
#  processing -> size_077.png
#  processing -> size_080.png
#  processing -> angle_000.png
#  processing -> angle_012.png
#  processing -> angle_024.png
#  processing -> angle_036.png
#  processing -> angle_048.png
#  processing -> angle_060.png
#  processing -> angle_072.png
#  processing -> angle_084.png
#  processing -> angle_096.png
#  processing -> angle_108.png
#  processing -> angle_120.png
#  processing -> angle_132.png
#  processing -> angle_144.png
#  processing -> angle_156.png
#  processing -> angle_168.png
#  processing -> angle_180.png
#  processing -> angle_192.png
#  processing -> angle_204.png
#  processing -> angle_216.png
#  processing -> angle_228.png
#  processing -> angle_240.png
#  processing -> angle_251.png
#  processing -> angle_264.png
#  processing -> angle_276.png
#  processing -> angle_288.png
#  processing -> angle_300.png
#  processing -> angle_312.png
#  processing -> angle_324.png
#  processing -> angle_336.png
#  processing -> angle_348.png
#  processing -> shadow_gap_000.png
#  processing -> shadow_gap_001.png
#  processing -> shadow_gap_002.png
#  processing -> shadow_gap_003.png
#  processing -> shadow_gap_004.png
#  processing -> shadow_gap_005.png
#  processing -> shadow_gap_006.png
#  processing -> shadow_gap_007.png
#  processing -> shadow_gap_008.png
#  processing -> shadow_gap_009.png
#  processing -> shadow_gap_010.png
#  processing -> shadow_gap_011.png
#  processing -> shadow_gap_012.png
#  processing -> shadow_gap_013.png
#  processing -> shadow_gap_014.png
#  processing -> shadow_gap_015.png
#  processing -> shadow_gap_016.png
#  processing -> shadow_gap_017.png
#  processing -> shadow_gap_018.png
#  processing -> shadow_gap_019.png
#  processing -> shadow_gap_020.png
#  processing -> shadow_gap_021.png
#  processing -> shadow_gap_022.png
#  processing -> shadow_gap_023.png
#  processing -> shadow_gap_024.png
#  processing -> shadow_gap_025.png
#  processing -> shadow_gap_026.png
#  processing -> shadow_gap_027.png
#  processing -> shadow_gap_028.png
#  processing -> shadow_gap_029.png
#  processing -> texture_slant_000.png
#  processing -> texture_slant_001.png
#  processing -> texture_slant_002.png
#  processing -> texture_slant_003.png
#  processing -> texture_slant_004.png
#  processing -> texture_slant_005.png
#  processing -> texture_slant_006.png
#  processing -> texture_slant_007.png
#  processing -> texture_slant_008.png
#  processing -> texture_slant_009.png
#  processing -> texture_slant_010.png
#  processing -> texture_slant_011.png
#  processing -> texture_slant_012.png
#  processing -> texture_slant_013.png
#  processing -> texture_slant_014.png
#  processing -> texture_slant_015.png
#  processing -> texture_slant_016.png
#  processing -> texture_slant_017.png
#  processing -> texture_slant_018.png
#  processing -> texture_slant_019.png
#  processing -> texture_slant_020.png
#  processing -> texture_slant_021.png
#  processing -> texture_slant_022.png
#  processing -> texture_slant_023.png
#  processing -> texture_slant_024.png
#  processing -> texture_slant_025.png
#  processing -> texture_slant_026.png
#  processing -> texture_slant_027.png
#  processing -> texture_slant_028.png
#  processing -> texture_slant_029.png
# dataset processing complete. total images: 450

# %% [markdown]
# ## 4. ROI Analysis: Depth Gap Measurement
#
# ### 4.1 Bounding-box tool adapted for a single model
#
# This is the same interactive ROI tool used in the main pipeline, adapted for a
# two-panel comparison (original + MiDaS) instead of four panels (original + V1 + V2 + V3).
#
# The tool opens each `cmp_*.png` comparison in a resizable OpenCV window. The user
# draws a bounding box on the first panel (the original image); the same box is
# mirrored automatically onto the MiDaS panel at the correct pixel offset.
#
# For each ROI, the tool records `mean_intensity` (a proxy for predicted depth) and,
# for every second ROI in a pair, `gap_with_prev_roi` (the depth gap delta_I between
# the two ROIs). Results are appended to `tfg_roi_metrics.csv`, using the same column
# format as the main pipeline so both CSVs can be compared directly.
#
# **Controls:** drag to draw a box, `s` to save and move to the next image,
# `r` to reset boxes on the current image, `n` to skip, `Esc` to exit.
#
# Note: this cell requires an active display and cannot run headlessly.

# %%
import cv2
import numpy as np
import os
import csv

rectangles = []
drawing = False
ix, iy = -1, -1
img_with_commands = None
raw_img = None
scale_ratio = 1.0
display_offset = 0
orig_offset = 0
banner_h = 40
num_panels = 2  # original + MiDaS only
last_category = ""

def draw_rect(event, x, y, flags, param):
    """handles click-and-drag to draw bounding boxes."""
    global ix, iy, drawing, img_with_commands, rectangles, display_offset, banner_h, num_panels

    if event == cv2.EVENT_LBUTTONDOWN:
        if y < banner_h: return  # ignore clicks on banner
        if x > display_offset: return  # force drawing on panel 1 only
        drawing = True
        ix, iy = x, y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            temp_img = img_with_commands.copy()
            for i in range(num_panels):
                nx1, nx2 = ix + i * display_offset, x + i * display_offset
                cv2.rectangle(temp_img, (nx1, iy), (nx2, y), (0, 255, 255), 1)
            cv2.imshow("tfg_lab_midas", temp_img)

    elif event == cv2.EVENT_LBUTTONUP:
        if drawing:
            drawing = False
            x1, x2 = min(ix, x), max(ix, x)
            y1, y2 = min(iy, y), max(iy, y)

            if x2 - x1 > 2 and y2 - y1 > 2:
                rectangles.append((x1, y1, x2, y2))
                for i in range(num_panels):
                    nx1, nx2 = x1 + i * display_offset, x2 + i * display_offset
                    cv2.rectangle(img_with_commands, (nx1, y1), (nx2, y2), (0, 255, 0), 2)
                    cv2.putText(img_with_commands, f"roi{len(rectangles)}", (nx1, y1-5),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 255, 0), 1)
                cv2.imshow("tfg_lab_midas", img_with_commands)

def run_midas_roi_experiment(results_path="../results/depth_map_comparisons/midas/baseline_dataset",
                              output_path="../results/roi_analysis/midas/baseline_dataset"):
    """
    Same ROI extraction logic as the main pipeline's run_tfg_experiment, but adapted
    for the two-panel MiDaS comparisons (original + MiDaS) instead of four panels.
    """
    global rectangles, img_with_commands, raw_img, scale_ratio, display_offset, orig_offset, banner_h, num_panels, last_category

    os.makedirs(output_path, exist_ok=True)
    csv_file = os.path.join(output_path, "tfg_roi_metrics.csv")

    if not os.path.exists(csv_file):
        with open(csv_file, mode='w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["category", "image", "model", "roi_id", "area_px", "mean_intensity", "gap_with_prev_roi"])

    for category in sorted(os.listdir(results_path)):
        cat_path = os.path.join(results_path, category)
        if not os.path.isdir(cat_path): continue

        if category != last_category:
            with open(csv_file, mode='a', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(["---", f"CATEGORY: {category.upper()}", "---", "---", "---", "---", "---"])
            last_category = category

        valid_ext = ('.png', '.jpg', '.jpeg', '.bmp')
        image_files = [f for f in os.listdir(cat_path) if f.lower().endswith(valid_ext)]

        for filename in image_files:
            print(f"\n--- analyzing: {filename} ---")

            target_path = os.path.join(cat_path, filename)
            raw_img = cv2.imread(target_path, cv2.IMREAD_GRAYSCALE)
            if raw_img is None: continue

            h, w_total = raw_img.shape

            # auto-detect offset logic (same as main pipeline, generalised to num_panels)
            analysis_region = raw_img[int(h*0.15):int(h*0.95), :]
            _, thresh = cv2.threshold(analysis_region, 240, 255, cv2.THRESH_BINARY_INV)
            col_sums = np.sum(thresh, axis=0)
            content_cols = np.where(col_sums > 20)[0]

            if len(content_cols) > 0:
                jumps = np.where(np.diff(content_cols) > 15)[0]
                clusters = []
                start_idx = 0
                for j in jumps:
                    clusters.append((content_cols[start_idx], content_cols[j]))
                    start_idx = j + 1
                clusters.append((content_cols[start_idx], content_cols[-1]))

                if len(clusters) >= num_panels:
                    centers = [(start + end) / 2.0 for start, end in clusters]
                    orig_offset = int(np.mean(np.diff(centers[:num_panels])))
                else:
                    orig_offset = w_total // num_panels
            else:
                orig_offset = w_total // num_panels

            max_w, max_h = 1800, 800
            scale_ratio = min(max_w/w_total, max_h/h, 1.0)
            new_w, new_h = int(w_total * scale_ratio), int(h * scale_ratio)
            display_offset = int(orig_offset * scale_ratio)

            base_display = cv2.cvtColor(cv2.resize(raw_img, (new_w, new_h)), cv2.COLOR_GRAY2BGR)

            img_with_commands = np.zeros((new_h + banner_h, new_w, 3), dtype=np.uint8)
            img_with_commands[banner_h:, :] = base_display

            cv2.putText(img_with_commands, "keys: [s] save | [r] reset | [n] next  --  DRAG to draw rectangles on panel 1",
                        (10, 25), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

            rectangles = []
            cv2.namedWindow("tfg_lab_midas", cv2.WINDOW_AUTOSIZE)
            cv2.setMouseCallback("tfg_lab_midas", draw_rect)

            break_all = False
            while True:
                cv2.imshow("tfg_lab_midas", img_with_commands)
                key = cv2.waitKey(1) & 0xFF

                if key == ord('s'):
                    out_img = cv2.cvtColor(raw_img, cv2.COLOR_GRAY2BGR)

                    with open(csv_file, mode='a', newline='') as f:
                        writer = csv.writer(f)
                        means = {"orig": [], "midas": []}

                        for i, (px1, py1, px2, py2) in enumerate(rectangles):
                            true_y1, true_y2 = py1 - banner_h, py2 - banner_h
                            ox1, oy1 = int(px1 / scale_ratio), int(true_y1 / scale_ratio)
                            ox2, oy2 = int(px2 / scale_ratio), int(true_y2 / scale_ratio)

                            area = (ox2 - ox1) * (oy2 - oy1)

                            roi_orig = raw_img[oy1:oy2, ox1:ox2]
                            roi_midas = raw_img[oy1:oy2, ox1 + orig_offset : ox2 + orig_offset]

                            mean_orig = round(np.mean(roi_orig), 2)
                            mean_midas = round(np.mean(roi_midas), 2)

                            means["orig"].append(mean_orig)
                            means["midas"].append(mean_midas)

                            gap_orig = round(abs(mean_orig - means["orig"][i-1]), 2) if i % 2 == 1 else 0.0
                            gap_midas = round(abs(mean_midas - means["midas"][i-1]), 2) if i % 2 == 1 else 0.0

                            writer.writerow([category, filename, "orig", i+1, area, mean_orig, gap_orig])
                            writer.writerow([category, filename, "midas", i+1, area, mean_midas, gap_midas])

                            for j, m_val in enumerate([mean_orig, mean_midas]):
                                curr_x1 = ox1 + j * orig_offset
                                curr_x2 = ox2 + j * orig_offset
                                cv2.rectangle(out_img, (curr_x1, oy1), (curr_x2, oy2), (0, 255, 0), 2)
                                cv2.putText(out_img, f"r{i+1}: {m_val}", (curr_x1, oy1-10),
                                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

                    out_dir = os.path.join(output_path, category)
                    os.makedirs(out_dir, exist_ok=True)
                    cv2.imwrite(os.path.join(out_dir, f"analisis_{filename}"), out_img)
                    print("  -> saved successfully.")
                    break

                elif key == ord('r'):
                    img_with_commands[banner_h:, :] = base_display
                    img_with_commands[:banner_h, :] = 0
                    cv2.putText(img_with_commands, "keys: [s] save | [r] reset | [n] next  --  DRAG to draw rectangles on panel 1",
                                (10, 25), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
                    rectangles = []

                elif key == ord('n'):
                    break

                elif key == 27:
                    break_all = True
                    break

            if break_all: break
        if break_all: break

    cv2.destroyAllWindows()

# run_midas_roi_experiment(results_path="../results/depth_map_comparisons/midas/baseline_dataset", output_path="../results/roi_analysis/midas/baseline_dataset")
# run_midas_roi_experiment(results_path="../results/depth_map_comparisons/midas/synthetic/", output_path="../results/roi_analysis/midas/synthetic/")
# run_midas_roi_experiment(results_path="../results/depth_map_comparisons/midas/minecraft", output_path="../results/roi_analysis/midas/minecraft")
# Out:
# --- analyzing: cmp_base_image.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_cube_walls.jpg ---
#   -> saved successfully.
#
# --- analyzing: cmp_cylinder_pattern.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_cylinder_pattern_bordered.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_high-low_filter.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_high_pass.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_low_pass.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_minecraft_version.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_no_cyllinders.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_no_walls.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_only_cylinders.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shepard_illusion.jpg ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_prior.jpg ---
#   -> saved successfully.
#
# --- analyzing: cmp_solid.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_solid_bordered.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_warped.png ---
#   -> saved successfully.

# %% [markdown]
# ### 4.2 ROI analysis on psychophysics sequences
#
# Run the same tool on the MiDaS psychophysics comparison panels, producing the
# data needed for the PSE/JND analysis in Section 5.

# %%
run_midas_roi_experiment(results_path="../results/depth_map_comparisons/midas/psychophysics", output_path="../results/roi_analysis/midas/psychophysics")
# Out:
# --- analyzing: cmp_angle_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_036.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_048.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_060.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_072.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_084.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_096.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_108.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_120.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_132.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_144.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_156.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_168.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_180.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_192.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_204.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_216.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_228.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_240.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_251.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_264.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_276.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_288.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_300.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_312.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_324.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_336.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_angle_348.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_blur_bias_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_033.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_041.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_049.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_057.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_066.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_074.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_082.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_091.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_099.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_107.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_115.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_124.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_132.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_140.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_148.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_157.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_165.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_173.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_182.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_190.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_198.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_206.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_215.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_223.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_231.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_contrast_240.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ebbinghaus_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_face_shading_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_figure_ground_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_horizon_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_kanizsa_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_occlusion_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ponzo_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_shadow_gap_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_031.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_034.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_036.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_038.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_041.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_043.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_046.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_048.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_051.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_053.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_055.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_058.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_060.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_063.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_065.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_067.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_070.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_072.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_075.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_077.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_size_080.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_00.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_01.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_02.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_03.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_04.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_05.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_06.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_07.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_08.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_09.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_10.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_11.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_12.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_13.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_14.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_15.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_16.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_17.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_18.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_19.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_20.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_21.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_22.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_23.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_24.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_25.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_26.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_27.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_28.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_step_29.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_000.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_001.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_002.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_003.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_004.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_005.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_006.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_007.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_008.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_009.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_010.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_011.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_012.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_013.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_014.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_015.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_016.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_017.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_018.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_019.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_020.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_021.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_022.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_023.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_024.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_025.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_026.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_027.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_028.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_texture_slant_029.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_050.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_063.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_077.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_091.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_105.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_118.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_132.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_146.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_160.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_174.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_187.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_201.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_215.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_229.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_243.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_256.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_270.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_284.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_298.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_312.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_325.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_339.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_353.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_367.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_381.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_394.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_408.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_422.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_436.png ---
#   -> saved successfully.
#
# --- analyzing: cmp_ypos_450.png ---
#   -> saved successfully.

# %% [markdown]
# ## 5. PSE and JND Analysis
#
# ### 5.1 Psychometric curve fitting for MiDaS
#
# This mirrors `analyze_all_models_comparison` from the main pipeline, but plots a
# single model (MiDaS) instead of V1/V2/V3, using the CSV produced in Section 4.2.
#
# The same thresholds are extracted via linear interpolation:
#
# - **PSE:** the stimulus step where delta_I crosses zero
# - **JND:** the distance from the PSE to the point where |delta_I| reaches 84%
#   of its maximum value (equivalent to one standard deviation of a cumulative
#   Gaussian)
#
# `run_full_midas_analysis` iterates over all experiment categories found in the
# CSV and calls `analyze_midas_comparison` for each one.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

def analyze_midas_comparison(csv_path, category_name, threshold_pct=0.84):
    try:
        df = pd.read_csv(csv_path)
    except FileNotFoundError:
        print(f"error: file {csv_path} not found")
        return

    df = df[df['category'] != '---']
    df['mean_intensity'] = pd.to_numeric(df['mean_intensity'], errors='coerce')
    df['roi_id'] = pd.to_numeric(df['roi_id'], errors='coerce')

    df['step'] = df['image'].str.extract(r'_(\d+)\.')[0].astype(float)
    df = df.dropna(subset=['step', 'mean_intensity'])
    df['step'] = df['step'].astype(int)

    cat_df = df[df['category'].str.strip() == category_name].copy()
    cat_df = cat_df.drop_duplicates(subset=['model', 'step', 'roi_id'], keep='last')

    if cat_df.empty: return

    color = '#d62728'  # distinct colour from V1/V2/V3 palette

    plt.figure(figsize=(12, 8))

    model_df = cat_df[cat_df['model'] == 'midas']
    if model_df.empty:
        print(f"no midas data found for category {category_name}")
        return

    r1 = model_df[model_df['roi_id'] == 1].sort_values('step')
    r2 = model_df[model_df['roi_id'] == 2].sort_values('step')

    if not r1.empty and not r2.empty:
        steps = r1['step'].values
        y_diff = r1.set_index('step')['mean_intensity'] - r2.set_index('step')['mean_intensity']
        y_values = y_diff.values

        line, = plt.plot(steps, y_values, color=color, linewidth=2, marker='o', alpha=0.8)

        # pse (crossover at zero)
        pse_x = None
        for i in range(len(steps) - 1):
            if y_values[i] * y_values[i+1] <= 0:
                weight = abs(y_values[i]) / (max(abs(y_values[i]) + abs(y_values[i+1]), 1e-6))
                pse_x = steps[i] + weight * (steps[i+1] - steps[i])
                plt.scatter([pse_x], [0], color=color, s=80, edgecolors='white', zorder=5)
                break

        # jnd (distance from pse to threshold)
        jnd_val = None
        max_delta = np.max(np.abs(y_values))
        threshold_target = max_delta * threshold_pct

        for i in range(len(steps) - 1):
            if pse_x is not None and steps[i] >= (pse_x - 1):
                if abs(y_values[i]) <= threshold_target <= abs(y_values[i+1]):
                    weight = (threshold_target - abs(y_values[i])) / (max(abs(y_values[i+1]) - abs(y_values[i]), 1e-6))
                    threshold_step = steps[i] + weight * (steps[i+1] - steps[i])
                    jnd_val = threshold_step - pse_x

                    plt.hlines(y=y_values[i+1] if y_values[i+1] > 0 else -threshold_target,
                               xmin=pse_x, xmax=threshold_step, color=color, linestyle=':', alpha=0.5)
                    plt.annotate('', xy=(threshold_step, 0), xytext=(pse_x, 0),
                                 arrowprops=dict(arrowstyle='<->', color=color, lw=1.5))
                    break

        pse_str = f"{pse_x:.2f}" if pse_x is not None else "n/a"
        jnd_str = f"{jnd_val:.2f}" if jnd_val is not None else "n/a"
        line.set_label(f'MiDaS | PSE: {pse_str} | \u2194 JND: {jnd_str}')

    plt.axhline(y=0, color='black', linewidth=1.2, alpha=0.5)
    plt.title(f'PSYCHOPHYSICAL ANALYSIS (MiDaS): {category_name.upper()}\nJND Threshold: {threshold_pct*100:.0f}%', fontsize=14)
    plt.xlabel('Stimulus Evolution (Step)')
    plt.ylabel('Depth Delta (Target - Context)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', frameon=True)
    plt.grid(True, linestyle=':', alpha=0.3)

    base_dir = "../results/psychophysics/midas"
    exp_dir = os.path.join(base_dir, category_name)
    if not os.path.exists(exp_dir): os.makedirs(exp_dir)

    save_path = os.path.join(exp_dir, f"psychophysics_midas_{category_name}.png")
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()
    print(f"saved successfully in: {save_path}")

def run_full_midas_analysis(csv_path):
    try:
        df = pd.read_csv(csv_path)
        categories = df[df['category'] != '---']['category'].unique()
        for cat in categories:
            analyze_midas_comparison(csv_path, cat)
    except Exception as e:
        print(f"error during analysis: {e}")

#to run the script:
run_full_midas_analysis("../results/roi_analysis/midas/psychophysics/tfg_roi_metrics.csv")
# Out:
# saved successfully in: ../results/psychophysics/midas\angle\psychophysics_midas_angle.png
# saved successfully in: ../results/psychophysics/midas\blur_bias\psychophysics_midas_blur_bias.png
# saved successfully in: ../results/psychophysics/midas\contrast\psychophysics_midas_contrast.png
# saved successfully in: ../results/psychophysics/midas\ebbinghaus\psychophysics_midas_ebbinghaus.png
# saved successfully in: ../results/psychophysics/midas\face_shading\psychophysics_midas_face_shading.png
# saved successfully in: ../results/psychophysics/midas\figure_ground\psychophysics_midas_figure_ground.png
# saved successfully in: ../results/psychophysics/midas\horizon\psychophysics_midas_horizon.png
# saved successfully in: ../results/psychophysics/midas\kanizsa\psychophysics_midas_kanizsa.png
# saved successfully in: ../results/psychophysics/midas\occlusion\psychophysics_midas_occlusion.png
# saved successfully in: ../results/psychophysics/midas\ponzo\psychophysics_midas_ponzo.png
# saved successfully in: ../results/psychophysics/midas\shadow_gap\psychophysics_midas_shadow_gap.png
# saved successfully in: ../results/psychophysics/midas\size\psychophysics_midas_size.png
# saved successfully in: ../results/psychophysics/midas\size_vs_position\psychophysics_midas_size_vs_position.png
# saved successfully in: ../results/psychophysics/midas\texture_slant\psychophysics_midas_texture_slant.png
# saved successfully in: ../results/psychophysics/midas\ypos\psychophysics_midas_ypos.png

# %% [markdown]
# ## 6. Video Export
#
# Psychophysics sequences are exported as MP4 videos at 15 fps for use in the
# project defence presentation. This uses the same `create_experiment_videos`
# function as the main pipeline, reading from `../data/psychophysics/` where
# the original stimulus frames are stored.

# %%
def create_experiment_videos(target_directory="../data/psychophysics", fps=15):
    """
    #generates lightweight mp4 videos for each experiment folder.
    #optimized for presentations with small file sizes and high compatibility.
    """
    #check if the provided target directory exists on the system
    if not os.path.exists(target_directory):
        #display error message if the path is invalid
        print(f"error: target directory {target_directory} not found")
        return

    #iterate through all subdirectories in the target path, sorted alphabetically
    for folder_name in sorted(os.listdir(target_directory)):
        #construct the full path to the current experiment folder
        folder_path = os.path.join(target_directory, folder_name)
        
        #verify that the current item is a directory and not a file
        if os.path.isdir(folder_path):
            #define a tuple of supported image file extensions
            valid_ext = ('.png', '.jpg', '.jpeg')
            #collect and sort all image files to ensure correct frame sequence
            image_files = sorted([f for f in os.listdir(folder_path) if f.lower().endswith(valid_ext)])
            
            #skip the current folder if no valid images are found inside
            if not image_files:
                #move to the next iteration in the loop
                continue
            
            #determine video dimensions using the first image in the list
            first_frame_path = os.path.join(folder_path, image_files[0])
            #load the image into memory using opencv
            first_frame = cv2.imread(first_frame_path)
            #handle cases where the image file might be corrupted or unreadable
            if first_frame is None: continue
            
            #extract the height, width, and channels from the image shape
            h, w, _ = first_frame.shape
            
            #set the output filename using the folder name as a base
            video_name = f"{folder_name}_summary.mp4"
            #join the filename with the folder path for local storage
            video_path = os.path.join(folder_path, video_name)
            
            #define the fourcc codec as mp4v for high compression and compatibility
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            #initialize the videowriter object with the specified parameters
            video_writer = cv2.VideoWriter(video_path, fourcc, fps, (w, h))
            
            #inform the user about the current video being generated
            print(f"compiling {video_name}...")
            
            #loop through the sorted list of image files to build the video
            for img_name in image_files:
                #load the individual frame file
                frame = cv2.imread(os.path.join(folder_path, img_name))
                #ensure the frame was loaded correctly before writing
                if frame is not None:
                    #append the current frame to the video file
                    video_writer.write(frame)
            
            #close the videowriter and finalize the mp4 file properly
            video_writer.release()
            #confirm successful saving of the video file
            print(f"-> saved: {video_path}")

#standard boilerplate for direct script execution
if __name__ == "__main__":
    #execute the video generation function with default settings
    #ensure your psychophysics_experiments folder is in the same directory
    create_experiment_videos()
# Out:
# compiling aerial_perspective_summary.mp4...
# -> saved: Psychophysics_results\aerial_perspective\aerial_perspective_summary.mp4
# compiling blur_bias_summary.mp4...
# -> saved: Psychophysics_results\blur_bias\blur_bias_summary.mp4
# compiling ebbinghaus_bias_summary.mp4...
# -> saved: Psychophysics_results\ebbinghaus_bias\ebbinghaus_bias_summary.mp4
# compiling figure_ground_bias_summary.mp4...
# -> saved: Psychophysics_results\figure_ground_bias\figure_ground_bias_summary.mp4
# compiling height_bias_summary.mp4...
# -> saved: Psychophysics_results\height_bias\height_bias_summary.mp4
# compiling hollow_face_bias_summary.mp4...
# -> saved: Psychophysics_results\hollow_face_bias\hollow_face_bias_summary.mp4
# compiling horizon_bias_summary.mp4...
# -> saved: Psychophysics_results\horizon_bias\horizon_bias_summary.mp4
# compiling kanizsa_bias_summary.mp4...
# -> saved: Psychophysics_results\kanizsa_bias\kanizsa_bias_summary.mp4
# compiling occlusion_bias_summary.mp4...
# -> saved: Psychophysics_results\occlusion_bias\occlusion_bias_summary.mp4
# compiling ponzo_bias_summary.mp4...
# -> saved: Psychophysics_results\ponzo_bias\ponzo_bias_summary.mp4
# compiling pse_conflict_summary.mp4...
# -> saved: Psychophysics_results\pse_conflict\pse_conflict_summary.mp4
# compiling relative_size_summary.mp4...
# -> saved: Psychophysics_results\relative_size\relative_size_summary.mp4
# compiling shading_bias_summary.mp4...
# -> saved: Psychophysics_results\shading_bias\shading_bias_summary.mp4
# compiling shadow_attachment_bias_summary.mp4...
# -> saved: Psychophysics_results\shadow_attachment_bias\shadow_attachment_bias_summary.mp4
# compiling texture_gradient_summary.mp4...
# -> saved: Psychophysics_results\texture_gradient\texture_gradient_summary.mp4
